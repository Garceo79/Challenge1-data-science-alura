# %% [markdown]
# #Reporte Final de Anlásis de Tiendas
# ---

# %% [markdown]
# ##Introducción
# El objetivo de este análisis es determinar cuál de las cuatro tiendas disponibles sería la mejor opción para que el Sr. Juan venda sus productos. Para tomar esta decisión, se analizaron diversos factores clave: los ingresos totales de cada tienda, las categorías de productos más y menos vendidas, las calificaciones promedio de los clientes, los productos destacados por ventas y el costo promedio de envío. Los resultados se muestran a continuación.
#
# <br>

# %% [markdown]
# ##Desarrollo del Análisis
# ---

# %% [markdown]
# ### ▸ Ingresos Totales
#
# Sumando todos los productos vendidos por cada tienda se obtiene que el ingreso total por tienda en millones es:
#
# ![image.png](data:image/png;base64,...)
#
# Los ingresos totales en millones de pesos por tienda son:
# - **Tienda 1**: \$1150.88
# - **Tienda 2**: \$1116.34
# - **Tienda 3**: \$1098.02
# - **Tienda 4**: \$1038.38
#
# >**Conclusión parcial**: La **Tienda 1** muestra más ingresos totales que el resto, lo que indica un buen volumen de ventas y posiblemente una base solida de clientes.

# %% [markdown]
# ### ▸ Categorías más y menos vendidas
#
# Realizando el conteo por categoría del producto se obtiene que las categorias más y menos vendidas son:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# En todas las tiendas, las categorías más populares son:
#
# - ▲ **Muebles**
# - ▲ **Electrónicos**
# - ▲ **Juguetes**
#
# Y las menos vendidas son:
#
# - ▼ **Instrumentos musicales**
# - ▼ **Libros**
# - ▼ **Artículos para el hogar**
#
# <br>
#
# > **Conclusión parcial:** Existe una **demanda fuerte** en sectores tecnológicos y de equipamiento del hogar y una **demanda debil**en articulos para el hogar y libros.
#
# <br>

# %% [markdown]
# ### ▸ Calificaciones promedio de clientes
#
# Calculando los promedios de calificación que dieron con los clientes con el servicio recibido en cada tienda tenemos el siguiente resultado:
#
# ![image.png](data:image/png;base64,...)
#
#
# Las calificaciones promedio por tiendo son:
# - **Tienda 1**: 3.97 / 5  ★
# - **Tienda 2**: 4.03 / 5  ★
# - **Tienda 3**: 4.04 / 5  ★
# - **Tienda 4**: 3.99 / 5  ★
#
# <br>
#
# > **Conclusión parcial:** La **Tienda 3** tiene la mejor calificación promedio. Esto puede estar relacionado con una mejor experiencia de compra o calidad de atención aunque cabe mencionar que la diferencia de promedio de calificación entre tiendas no es demasiado grande.
#
# <br>

# %% [markdown]
# ### ▸ Productos más y menos vendidos
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# Se analizan los productos más y menos vendidos y el resultado es el siguiente:
#
#
# | Tienda     | ▲ Producto más vendido         | Cantidad | ▼ Producto menos vendido          | Cantidad |
# |------------|------------------------------|----------|----------------------------------|----------|
# | Tienda 1   | TV LED UHD 4K                | 60       | Celular ABXY                     | 33       |
# | Tienda 2   | Iniciando en programación    | 65       | Juego de mesa                    | 32       |
# | Tienda 3   | Kit de bancas                | 57       | Bloques de construcción          | 35       |
# | Tienda 4   | Cama box                     | 62       | Guitarra eléctrica               | 33       |
#
# <br>
#
# > **Conclusión parcial:** La **Tienda 2** tiene el producto más vendido en cantidad, lo cual indica fuerte rotación, pero las otras tiendas también tienen productos destacados.
#
# <br>

# %% [markdown]
# ### ▸ Costo promedio de envío
# Calculando el promedio  del costo de envío por cada tienda se obtiene el siguiente resultado:
#
# ![image.png](data:image/png;base64,...)
#
# Enseguida se muestran los resultados obtenidos de forma númerica:
#
# - **Tienda 1**: \$26,018.61
# - **Tienda 2**: \$25,216.24
# - **Tienda 3**: \$24,805.68
# - **Tienda 4**: \$23,459.46
#
# > **Conclusión parcial:** La **Tienda 4** tiene el costo de envío más bajo, lo cual puede ser llamativo para compradores. Sin embargo, no tiene el mejor desempeño en otras métricas.
#
# <br>

# %% [markdown]
# ## Conclusión y Recomendación
# ---

# %% [markdown]
# Si bien la **Tienda 1** destaca en ingresos totales, su calificación promedio es la más baja (3.97 / 5 ★) y sus costos de envío son los más altos. Por otro lado, la **Tienda 3** combina muy bien:
#
# - Alta satisfacción del cliente (**4.04** ★)
# - Costo de envío razonable
# - Buen volumen de ventas
#
# La **Tienda 2** también es competitiva, con un producto muy vendido y buena calificación, aunque con menor ingreso total que la Tienda 1.
#
# <br>

# %% [markdown]
# > **Recomendación final:**
# >
# > Se recomienda que el Sr. Juan venda sus productos en la **Tienda 3**, ya que ofrece el mejor balance entre **calidad percibida por los clientes**, **costos de operación razonables** y **buen desempeño en ventas**. Esta tienda se perfila como la más confiable para generar ingresos sostenidos con alto nivel de satisfacción del cliente.

# %% [markdown]
# # Importación de datos

# %% [markdown]
# Antes de pasar a análisis detallados, es esencial explorar el conjunto de datos para comprender su estructura y contenido. Este paso le permite identificar patrones, inconsistencias y las columnas más relevantes para los siguientes pasos.
#
# **Estructura de datos:**
# El conjunto de datos incluye la siguiente información:
#
# - **Producto y Categoría:** Artículos vendidos y sus calificaciones.
#
# - **Precio y Envío:** Valores de venta y costos asociados.
#
# - **Fecha y ubicación de compra:** Información temporal y geográfica.
#
# - **Evaluación de compra:** Comentarios de clientes.
#
# - **Tipo de Pago y Cuotas:** Métodos utilizados por los clientes.
#
# - **Coordenadas Geográficas:** Ubicación de las transacciones.

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.
# https://www.aluracursos.com/blog/listas-de-python-operaciones-basicas

# %%
millon = 1000000
total_por_tienda = {'Tienda 1': tienda['Precio'].sum()/millon,
                    'Tienda 2': tienda2['Precio'].sum()/millon,
                    'Tienda 3': tienda3['Precio'].sum()/millon,
                    'Tienda 4': tienda4['Precio'].sum()/millon}

# %%
for i, total in total_por_tienda.items():
  print(i, ':', f"${total:.2f} millones")
# Out:
# Tienda 1 : $1150.88 millones
# Tienda 2 : $1116.34 millones
# Tienda 3 : $1098.02 millones
# Tienda 4 : $1038.38 millones

# %%
import matplotlib.pyplot as plt

# %%
#Grafico de barras
eje_x = total_por_tienda.keys()
eje_y = [round(value,2) for value in total_por_tienda.values()]
valor_maximo=eje_y.index(max(eje_y))

#Size
plt.figure(figsize=(8, 6))

#Data and type chart
barras = plt.bar(eje_x, eje_y, color='skyblue')
barras[valor_maximo].set_color('deepskyblue')

#Labels
plt.xlabel('')
plt.ylabel('Millones de pesos')
plt.title('Ingreso Total por Tienda',fontdict={'fontsize': 16, 'fontweight': 'bold'},loc='left',y=1.02)

#Format
plt.grid(linestyle = '--', linewidth = 0.3, color = 'gray', axis= 'y')

# Adding annotations
for i, value in enumerate(eje_y):
    plt.text(i, value, f"${value}M", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
def contar_valores_unicos(df):
    #Cuenta los valores únicos de la columna mencionada y convierte el series a dataframe
    valores_diferentes = df['Categoría del Producto'].value_counts().to_dict()
    return valores_diferentes

# %%
categorias_tiendas = [contar_valores_unicos(tienda),
                      contar_valores_unicos(tienda2),
                      contar_valores_unicos(tienda3),
                      contar_valores_unicos(tienda4)]

# %%
categorias_tiendas = pd.DataFrame(categorias_tiendas, index=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'])
categorias_tiendas
# Out:
#           Muebles  Electrónicos  Juguetes  Electrodomésticos  \
# Tienda 1      465           448       324                312
# Tienda 2      442           422       313                305
# Tienda 3      499           451       315                278
# Tienda 4      480           451       338                254
#
#           Deportes y diversión  Instrumentos musicales  Libros  \
# Tienda 1                   284                     182     173
# Tienda 2                   275                     224     197
# Tienda 3                   277                     177     185
# Tienda 4                   277                     170     187
#
#           Artículos para el hogar
# Tienda 1                      171
# Tienda 2                      181
# Tienda 3                      177
# Tienda 4                      201

# %%
#def grafico_dona(df):

for nombre in categorias_tiendas.index:
  df = categorias_tiendas.loc[nombre]

  num_colors = len(categorias_tiendas.loc[nombre])
  cmap = plt.get_cmap('Blues')#Mapa de colores azul con la 'r' se invierte el mapa
  colors = [cmap(i / (num_colors - 1)) for i in range(num_colors)]

  plt.figure(figsize=(6, 6))
  wedges, texts, autotexts = plt.pie(df.values,
          labels=df.index,
          autopct='%1.2f%%',
          colors=colors,
          wedgeprops={'width':0.4},
          pctdistance=0.8,
          startangle=140)

  plt.setp(autotexts, size=6, weight="regular", color="black")  # Estilo del % en el gráfico
  plt.title(f'Distribución por Categoría - {nombre}', fontsize=14)
  plt.axis('equal')  # mantener círculo
  plt.tight_layout()
  plt.show()

# %%
def grafico_barras_horizontal(dict, tienda):

  #Grafico de barras
  eje_x = dict.keys()
  eje_y = dict.values()

  #Size
  plt.figure(figsize=(8, 4))

  #Data and type chart
  plt.barh(eje_x, eje_y, color='skyblue')

  #Labels
  plt.xlabel('')
  plt.ylabel('')
  plt.title(f'Número de ventas por categoría de la {tienda}',fontdict={'fontsize': 16, 'fontweight': 'bold'},loc='left',y=1)

  #Format
  plt.grid(linestyle = '--', linewidth = 0.3, color = 'gray', axis= 'x')

  # Adding annotations
  for i, value in enumerate(eje_y):
      plt.text(value, i, str(value), ha='left', va='center')

# %%
#plt.show(grafico_barras_horizontal(categorias_tienda, 'Tienda 1'))

# %%
#plt.show(grafico_barras_horizontal(categorias_tienda_2, 'Tienda 2'))

# %%
#plt.show(grafico_barras_horizontal(categorias_tienda_3, 'Tienda 3'))

# %%
#plt.show(grafico_barras_horizontal(categorias_tienda_4, 'Tienda 4'))

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()

# %%
promedio1 = tienda1['Calificación'].mean().round(2)
promedio2 = tienda2['Calificación'].mean().round(2)
promedio3 = tienda3['Calificación'].mean().round(2)
promedio4 = tienda4['Calificación'].mean().round(2)

# %%
promedios = {'Tienda 1': promedio1,
             'Tienda 2': promedio2,
             'Tienda 3': promedio3,
             'Tienda 4': promedio4}
promedios

# %%
def grafico_barras_vertical(dict):

  df = pd.DataFrame(dict.items(), columns=['Tienda', 'Promedio'])
  df = df.sort_values(by='Promedio', ascending=False)

  #Grafico de barras
  eje_x = df['Tienda']
  eje_y = df['Promedio']

  valor_maximo = eje_y.idxmax()
  valor_maximo_index = df.index.get_loc(valor_maximo)

  #Size
  plt.figure(figsize=(8, 4))

  #Data and type chart
  barras = plt.barh(eje_x, eje_y, color='skyblue')
  barras[valor_maximo_index].set_color('deepskyblue')

  #Labels
  plt.xlabel('')
  plt.xlim(0, 5)
  plt.ylabel('')
  plt.title('Promedio de calificaciones por cada tienda',fontdict={'fontsize': 16, 'fontweight': 'bold'},loc='left',y=1)

  #Format
  plt.grid(linestyle = '--', linewidth = 0.3, color = 'gray', axis= 'x')

  # Adding annotations
  for i, value in enumerate(eje_y):
          plt.text(value, i, str(value), ha='center', va='bottom')

# %%
plt.show(grafico_barras_vertical(promedios))

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()

# %%
def contar_productos(df):
    #Cuenta los valores únicos de la columna mencionada y convierte el series a dataframe
    valores_unicos = df['Producto'].value_counts().to_dict()
    valores_unicos_ordenados = pd.DataFrame(valores_unicos.items(),
                                            columns=['Producto', 'Total']).sort_values(by='Total')

    return valores_unicos_ordenados

# %%
productos_tienda1 = contar_productos(tienda1)
productos_tienda2 = contar_productos(tienda2)
productos_tienda3 = contar_productos(tienda3)
productos_tienda4 = contar_productos(tienda4)

# %%
def grafico_barras_horizontal(df, tienda):

  #Grafico de barras
  eje_x1 = df['Producto'].head(3)
  eje_x2 = df['Producto'].tail(3)
  eje_y1 = df['Total'].head(3)
  eje_y2 = df['Total'].tail(3)

  values_y =pd.concat([eje_y1, eje_y2])

  #Size
  plt.figure(figsize=(6, 3))

  #Data and type chart
  plt.barh(eje_x1, eje_y1, color='skyblue')
  plt.barh(eje_x2, eje_y2, color='deepskyblue')

  #Labels
  plt.xlabel('')
  plt.xlim(0, 70)
  plt.ylabel('')
  plt.title(f'Número de ventas por categoría de la {tienda}',fontdict={'fontsize': 11, 'fontweight': 'bold'},loc='left',y=1)

  #Format
  plt.grid(linestyle = '--', linewidth = 0.3, color = 'gray', axis= 'x')

  # Adding annotations
  for i, value in enumerate(values_y):
      plt.text(value, i, str(value), ha='left', va='center')

# %%
plt.show(grafico_barras_horizontal(productos_tienda1, 'Tienda 1'))
plt.show(grafico_barras_horizontal(productos_tienda2, 'Tienda 2'))
plt.show(grafico_barras_horizontal(productos_tienda3, 'Tienda 3'))
plt.show(grafico_barras_horizontal(productos_tienda4, 'Tienda 4'))

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
promedio1 = tienda1['Costo de envío'].mean().round(2)
promedio2 = tienda2['Costo de envío'].mean().round(2)
promedio3 = tienda3['Costo de envío'].mean().round(2)
promedio4 = tienda4['Costo de envío'].mean().round(2)

# %%
promedios_costo_envio = {'Tienda 1': promedio1,
             'Tienda 2': promedio2,
             'Tienda 3': promedio3,
             'Tienda 4': promedio4}
promedios_costo_envio
# Out:
# {'Tienda 1': np.float64(26018.61),
#  'Tienda 2': np.float64(25216.24),
#  'Tienda 3': np.float64(24805.68),
#  'Tienda 4': np.float64(23459.46)}

# %%
def grafico_barras_vertical(dict):

  df = pd.DataFrame(dict.items(), columns=['Tienda', 'Promedio'])
  df = df.sort_values(by='Promedio', ascending=False)

  #Grafico de barras
  eje_x = df['Tienda']
  eje_y = df['Promedio']

  #Size
  plt.figure(figsize=(8, 4))

  #Data and type chart
  plt.bar(eje_x, eje_y, color='skyblue')

  #Labels
  plt.xlabel('')
  plt.ylabel('')
  plt.title('Promedio de costo de envío por cada tienda',fontdict={'fontsize': 16, 'fontweight': 'bold'},loc='left',y=1)

  #Format
  plt.grid(linestyle = '--', linewidth = 0.3, color = 'gray', axis= 'y')

  # Adding annotations
  for i, value in enumerate(eje_y):
          plt.text(i, value, str(value), ha='center', va='bottom')

# %%
grafico_barras_vertical(promedios_costo_envio)

# %% [markdown]
# #6. Ubicación de compras

# %%
import folium as fl
from IPython.display import display

# %%
#Map configurations
#stamen_attribution = ('&copy; <a href="https://stamen.com/" target="_blank">Stamen Design</a>'
                      # '&copy; <a href="https://stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a>'
                      # '&copy; <a href="https://www.openstreetmap.org/copyright" target="_blank">OpenStreetMap</a> contributors'
                      # '&copy; <a href="https://stamen.com/" target="_blank">Stamen Design</a>'
                      # )
map = fl.Map(
          location=[38.58,-99.09],
          zoom_start=6,
          #tiles='Stamen Terrain'
          #attr=stamen_attribution
          )

#Marker Configuration
fg = fl.FeatureGroup(name="My Map")

for coordinates in [[38.2,-99.1],[39.2,-97.1]]:
  fg.add_child(fl.Marker(
      location=coordinates,
      popup="I´m here",
      icon=fl.Icon(color="green")
      )
  )

#Crear the objet
map.add_child(fg)
map.add_child(fl.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map.save("MapaCompras.html")
